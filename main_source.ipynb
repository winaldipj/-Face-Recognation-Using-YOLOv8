# %%
# YOLO v8
from ultralytics import YOLO

# Library Standard
import torch, cv2, math

# %% [markdown]
# Model Pretrained Yolo

# %% [markdown]
# https://github.com/ultralytics/assets/releases/

# %%
custom_data_path = 'D:/Source Code/Python/DeepLearning/CNN/ObJectDetection/Custom_Face_Detection_YOLOv8/datasets/custom_data/Custom_Data.yaml'

# %%
model = YOLO('yolov8n.yaml')
model = YOLO('yolov8n.pt')
model.train(data=custom_data_path, epochs=100)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %% [markdown]
# Load Model And Try The Real Time

# %%
model = YOLO('runs/detect/train/weights/best.pt')

# %%
cap=cv2.VideoCapture(0)

classNames = ['Najla','Tiara','Abdul','Levian',
              'Mufita','Budi','Ridho','Winaldi']

while True:
    success, frame = cap.read()
    results=model(frame,stream=True)

    for r in results:
        boxes=r.boxes

        for box in boxes:
            x1,y1,x2,y2=box.xyxy[0]
            x1,y1,x2,y2=int(x1), int(y1), int(x2), int(y2)
            print(x1,y1)

            cv2.rectangle(frame, (x1,y1), (x2,y2), (255,0,255),3)
            conf=math.ceil((box.conf[0]*100))/100
            cls=int(box.cls[0])
            
            class_name=classNames[cls]
            label=f'{class_name}{conf}'
            t_size = cv2.getTextSize(label, 0, fontScale=1, thickness=2)[0]
            c2 = x1 + t_size[0], y1 - t_size[1] - 3
            cv2.rectangle(frame, (x1,y1), c2, [255,0,255], -1, cv2.LINE_AA)  # filled
            cv2.putText(frame, label, (x1,y1-2),0, 1,[255,255,255], thickness=1,lineType=cv2.LINE_AA)

    cv2.imshow("Image", frame)
    if cv2.waitKey(1) & 0xFF==ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 Winaldi, 368.2ms
# Speed: 6.0ms preprocess, 368.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 264 161
# 0: 480x640 1 Winaldi, 481.8ms
# Speed: 7.0ms preprocess, 481.8ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# 275 165
# 0: 480x640 1 Winaldi, 482.8ms
# Speed: 10.0ms preprocess, 482.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# 266 167
# 0: 480x640 1 Winaldi, 414.3ms
# Speed: 6.5ms preprocess, 414.3ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# 265 168
# 0: 480x640 1 Winaldi, 431.2ms
# Speed: 6.0ms preprocess, 431.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# 273 165
